# %%
GO DIRECTLY TO CELL 34 To Access Processed DATA

# %%
import pandas as pd
import re
import matplotlib.pyplot as pt
import seaborn as sns
import numpy as np

# %%
# Loading the datset
df = pd.read_csv("../../data/raw/ProfileData/vivah_profiles_clean.csv")
print("No of Profiles" ,df.shape[0], " & no of features ",df.shape[1])
df.head()
# Out:
# No of Profiles 300  & no of features  8
#   Profile ID Religion               Caste Mother Tongue  \
# 0    VVZ5841   Hindu              Maratha       English
# 1    VVF8907  Muslim               Hanafi          Urdu
# 2    VVH2947   Hindu    Brahmin Himachali         Hindi
# 3    VVF8880   Hindu                 Koli       Kannada
# 4    VHQ0512   Hindu               Kuruba       Kannada
#
#                  Age, Height           Profession  \
# 0  26 Yrs,   5ft 4in - 162cm            Scientist
# 1  21 Yrs,   5ft 1in - 154cm          Not Working
# 2  35 Yrs,   5ft 4in - 162cm          Not Working
# 3  30 Yrs,   5ft 4in - 162cm               Doctor
# 4  30 Yrs,   5ft 4in - 162cm  Admin/ Front Office
#
#                                Education                           Location
# 0                    Masters in Medicine  India - Maharashtra - Navi Mumbai
# 1  Bachelors in Nursing/ Health Sciences      India - Telangana - Hyderabad
# 2                  Bachelors in Commerce  India - Himachal Pradesh - Shimla
# 3                    Masters in Medicine          India - Karnataka - Bidar
# 4                  Bachelors in Commerce      India - Karnataka - Bangalore

# %%
# In the dataset age and height is given in  "Age, Height" <-- format
# Creating two new column Age and height from it
def normalize_age_height_column(val):
    age_val = re.search(r'(\d+)\s*Yrs',val  ,flags=re.IGNORECASE)
    height_val = re.search(r'(\d+)\s*cm',val,flags=re.IGNORECASE)
    age = int(age_val.group(1)) if age_val else None
    height = int(height_val.group(1)) if height_val else None
    return age,height #Outputs tuple
def add_FeetInchColumnfromcm(cm):
    if pd.isna(cm):
        return None
    total_inches = int(round(cm/2.54))
    feet = total_inches//12
    inch = total_inches%12
    return f"{feet}ft {inch}in"

df[['Age','Height']] = df['Age, Height'].apply(lambda x : pd.Series(normalize_age_height_column(x)))
df["Height_ft_in"] = df['Height'].apply(add_FeetInchColumnfromcm)
df.drop(columns=['Age, Height'], inplace=True)

df.head()
# Out:
#   Profile ID Religion               Caste Mother Tongue           Profession  \
# 0    VVZ5841   Hindu              Maratha       English            Scientist
# 1    VVF8907  Muslim               Hanafi          Urdu          Not Working
# 2    VVH2947   Hindu    Brahmin Himachali         Hindi          Not Working
# 3    VVF8880   Hindu                 Koli       Kannada               Doctor
# 4    VHQ0512   Hindu               Kuruba       Kannada  Admin/ Front Office
#
#                                Education                           Location  \
# 0                    Masters in Medicine  India - Maharashtra - Navi Mumbai
# 1  Bachelors in Nursing/ Health Sciences      India - Telangana - Hyderabad
# 2                  Bachelors in Commerce  India - Himachal Pradesh - Shimla
# 3                    Masters in Medicine          India - Karnataka - Bidar
# 4                  Bachelors in Commerce      India - Karnataka - Bangalore
#
#    Age  Height Height_ft_in
# 0   26     162      5ft 4in
# 1   21     154      5ft 1in
# 2   35     162      5ft 4in
# 3   30     162      5ft 4in
# 4   30     162      5ft 4in

# %%
df.rename(columns={"Height" : "Height in cm"}, inplace=True)
df.head()
# Out:
#   Profile ID Religion               Caste Mother Tongue           Profession  \
# 0    VVZ5841   Hindu              Maratha       English            Scientist
# 1    VVF8907  Muslim               Hanafi          Urdu          Not Working
# 2    VVH2947   Hindu    Brahmin Himachali         Hindi          Not Working
# 3    VVF8880   Hindu                 Koli       Kannada               Doctor
# 4    VHQ0512   Hindu               Kuruba       Kannada  Admin/ Front Office
#
#                                Education                           Location  \
# 0                    Masters in Medicine  India - Maharashtra - Navi Mumbai
# 1  Bachelors in Nursing/ Health Sciences      India - Telangana - Hyderabad
# 2                  Bachelors in Commerce  India - Himachal Pradesh - Shimla
# 3                    Masters in Medicine          India - Karnataka - Bidar
# 4                  Bachelors in Commerce      India - Karnataka - Bangalore
#
#    Age  Height in cm Height_ft_in
# 0   26           162      5ft 4in
# 1   21           154      5ft 1in
# 2   35           162      5ft 4in
# 3   30           162      5ft 4in
# 4   30           162      5ft 4in

# %%
# Splitting composite column for locaiton into CITY, STATE, COUNTRY
df[['Country','State','City']] = df['Location'].str.split(" - ", expand=True,n=2)
df.drop(columns=["Location"],inplace=True) 
df.head()
# Out:
#   Profile ID Religion               Caste Mother Tongue           Profession  \
# 0    VVZ5841   Hindu              Maratha       English            Scientist
# 1    VVF8907  Muslim               Hanafi          Urdu          Not Working
# 2    VVH2947   Hindu    Brahmin Himachali         Hindi          Not Working
# 3    VVF8880   Hindu                 Koli       Kannada               Doctor
# 4    VHQ0512   Hindu               Kuruba       Kannada  Admin/ Front Office
#
#                                Education  Age  Height in cm Height_ft_in  \
# 0                    Masters in Medicine   26           162      5ft 4in
# 1  Bachelors in Nursing/ Health Sciences   21           154      5ft 1in
# 2                  Bachelors in Commerce   35           162      5ft 4in
# 3                    Masters in Medicine   30           162      5ft 4in
# 4                  Bachelors in Commerce   30           162      5ft 4in
#
#   Country             State         City
# 0   India       Maharashtra  Navi Mumbai
# 1   India         Telangana    Hyderabad
# 2   India  Himachal Pradesh       Shimla
# 3   India         Karnataka        Bidar
# 4   India         Karnataka    Bangalore

# %%
# Converting all string or categorical values into lowercase 
# and removing all whotespace
text_Categorical_cols = ['Religion', 'Caste', 'Mother Tongue', 'Profession', 'Education', 'Country', 'State', 'City']
for column in text_Categorical_cols:
    df[column] = df[column].str.lower().str.strip()

# %%
# Handling missing data for both Numerical and categorical value in dataset
df[text_Categorical_cols] = df[text_Categorical_cols].fillna("unknown")
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Height in cm"] = df["Height in cm"].fillna(df["Height in cm"].median())
# df.drop(columns=["Height_cm"],inplace=True)

# %%
# Saving the processed data
df.to_csv("processed_vivah_profiles.csv",index=False)

# %%
df = pd.read_csv("../../data/processed/ProfileData/processed_vivah_profiles.csv")
print(df.columns)
# Out:
# Index(['Profile ID', 'Religion', 'Caste', 'Mother Tongue', 'Profession',
#        'Education', 'Age', 'Height in cm', 'Height_ft_in', 'Country', 'State',
#        'City'],
#       dtype='object')

# %%
print("No of religions considered ", df["Religion"].nunique())

print("These Religions are",df["Religion"].value_counts())
# Out:
# No of religions considered  3
# These Religions are Religion
# hindu       240
# muslim       30
# buddhist     30
# Name: count, dtype: int64

# %%
print("No of Casts considered ", df["Caste"].nunique())

print("These Castes are",df["Caste"].value_counts())
# Out:
# No of Casts considered  10
# These Castes are Caste
# maratha              30
# hanafi               30
# brahmin himachali    30
# koli                 30
# kuruba               30
# brahmin              30
# buddhist             30
# rajput               30
# vishwakarma          30
# brahmin gour         30
# Name: count, dtype: int64

# %%
print("Type of Educational Qualifications  considered ", df["Education"].nunique())

print("These Qualifications are",df["Education"].value_counts())
# Out:
# Type of Educational Qualifications  considered  7
# These Qualifications are Education
# bachelors in commerce                    90
# masters in medicine                      60
# bachelors in nursing/ health sciences    30
# high school in arts                      30
# other in fashion                         30
# masters in finance                       30
# bachelors in arts                        30
# Name: count, dtype: int64

# %%
print("Unique States:", df['State'].nunique())
print(df['State'].value_counts().head(10))


print("Unique Professions:", df['Profession'].nunique())
print(df['Profession'].value_counts().head(10))
# Out:
# Unique States: 8
# State
# maharashtra         60
# karnataka           60
# telangana           30
# himachal pradesh    30
# delhi               30
# uttar pradesh       30
# jharkhand           30
# odisha              30
# Name: count, dtype: int64
# Unique Professions: 7
# Profession
# not working             120
# scientist                30
# doctor                   30
# admin/ front office      30
# other                    30
# consultant               30
# chartered accountant     30
# Name: count, dtype: int64

# %%
# Dropping useless columns
df = df.drop(columns=["Profile ID"])
df.columns
# Out:
# Index(['Religion', 'Caste', 'Mother Tongue', 'Profession', 'Education', 'Age',
#        'Height in cm', 'Height_ft_in', 'Country', 'State', 'City'],
#       dtype='object')

# %%
# Add missing essential columns with default/random values
# geder
if "Gender" not in df.columns:
    df["Gender"] = np.random.choice(["Male", "Female"], size=len(df))
df["Gender"].value_counts()
df.columns
# Out:
# Index(['Religion', 'Caste', 'Mother Tongue', 'Profession', 'Education', 'Age',
#        'Height in cm', 'Height_ft_in', 'Country', 'State', 'City', 'Gender'],
#       dtype='object')

# %%
# Ensure all expected columns are present
expected_cols = [
    "Independency","Previous Marriage", "Addiction",  "Height Ratio", 
    "Income"
]

# %%
def normalize_education(x):
    x = str(x).lower()
    if "phd" in x or "doctorate" in x:
        return "PhD"
    elif "master" in x or "postgraduate" in x:
        return "Postgraduate"
    elif "bachelor" in x or "graduate" in x:
        return "Graduate"
    elif "school" in x or "diploma" in x:
        return "School"
    else:
        return "Other"

df["Education"] = df["Education"].apply(normalize_education)

# %%
def infer_income(prof):
    p = str(prof).lower()
    if any(w in p for w in ["doctor", "engineer", "scientist", "software", "it", "manager"]):
        return "High"
    elif any(w in p for w in ["teacher", "nurse", "clerk", "sales", "govt"]):
        return "Medium"
    else:
        return "Low"

df["Income"] = df["Profession"].apply(infer_income)

# %%
# --- Independency (random choice: Low, Medium, High) ---
df["Independency"] = np.random.choice(["Low", "Medium", "High"], size=len(df))

# --- Previous Marriage (random binary: 0 = No, 1 = Yes, with bias towards 0) ---
df["Previous Marriage"] = np.random.choice([0, 1], size=len(df), p=[0.9, 0.1])

# --- Addiction (random Yes/No, mostly No) ---
df["Addiction"] = np.random.choice(["No", "Yes"], size=len(df), p=[0.85, 0.15])

# %%
df.head(20)
# Out:
#     Religion              Caste Mother Tongue            Profession  \
# 0      hindu            maratha       english             scientist
# 1     muslim             hanafi          urdu           not working
# 2      hindu  brahmin himachali         hindi           not working
# 3      hindu               koli       kannada                doctor
# 4      hindu             kuruba       kannada   admin/ front office
# 5      hindu            brahmin       punjabi           not working
# 6   buddhist           buddhist       marathi                 other
# 7      hindu             rajput       kumoani            consultant
# 8      hindu        vishwakarma      bhojpuri  chartered accountant
# 9      hindu       brahmin gour         hindi           not working
# 10     hindu            maratha       english             scientist
# 11    muslim             hanafi          urdu           not working
# 12     hindu  brahmin himachali         hindi           not working
# 13     hindu               koli       kannada                doctor
# 14     hindu             kuruba       kannada   admin/ front office
# 15     hindu            brahmin       punjabi           not working
# 16  buddhist           buddhist       marathi                 other
# 17     hindu             rajput       kumoani            consultant
# 18     hindu        vishwakarma      bhojpuri  chartered accountant
# 19     hindu       brahmin gour         hindi           not working
#
#        Education  Age  Height in cm Height_ft_in Country             State  \
# 0   Postgraduate   26           162      5ft 4in   india       maharashtra
# 1       Graduate   21           154      5ft 1in   india         telangana
# 2       Graduate   35           162      5ft 4in   india  himachal pradesh
# 3   Postgraduate   30           162      5ft 4in   india         karnataka
# 4       Graduate   30           162      5ft 4in   india         karnataka
# 5         School   35           152      5ft 0in   india             delhi
# 6          Other   33           157      5ft 2in   india       maharashtra
# 7   Postgraduate   32           162      5ft 4in   india     uttar pradesh
# 8       Graduate   35           152      5ft 0in   india         jharkhand
# 9       Graduate   22           132      4ft 4in   india            odisha
# 10  Postgraduate   26           162      5ft 4in   india       maharashtra
# 11      Graduate   21           154      5ft 1in   india         telangana
# 12      Graduate   35           162      5ft 4in   india  himachal pradesh
# 13  Postgraduate   30           162      5ft 4in   india         karnataka
# 14      Graduate   30           162      5ft 4in   india         karnataka
# 15        School   35           152      5ft 0in   india             delhi
# 16         Other   33           157      5ft 2in   india       maharashtra
# 17  Postgraduate   32           162      5ft 4in   india     uttar pradesh
# 18      Graduate   35           152      5ft 0in   india         jharkhand
# 19      Graduate   22           132      4ft 4in   india            odisha
#
#              City  Gender Income Independency  Previous Marriage Addiction
# 0     navi mumbai  Female   High          Low                  0        No
# 1       hyderabad  Female    Low          Low                  0        No
# 2          shimla  Female    Low       Medium                  0        No
# 3           bidar  Female   High         High                  0       Yes
# 4       bangalore  Female    Low       Medium                  0        No
# 5       new delhi  Female    Low          Low                  0        No
# 6          wardha    Male    Low       Medium                  0        No
# 7   greater noida    Male    Low       Medium                  0        No
# 8      jamshedpur  Female    Low         High                  0        No
# 9         cuttack  Female    Low          Low                  1        No
# 10    navi mumbai    Male   High       Medium                  0       Yes
# 11      hyderabad    Male    Low          Low                  0       Yes
# 12         shimla  Female    Low         High                  1        No
# 13          bidar    Male   High       Medium                  0        No
# 14      bangalore    Male    Low         High                  0        No
# 15      new delhi    Male    Low       Medium                  0        No
# 16         wardha  Female    Low          Low                  0       Yes
# 17  greater noida  Female    Low         High                  0        No
# 18     jamshedpur  Female    Low          Low                  0        No
# 19        cuttack    Male    Low       Medium                  0        No

# %%
df.to_csv("processed_vivah_profiles.csv",index=False)

# %%
df = pd.read_csv("processed_vivah_profiles.csv")
df.head(20)
# Out:
#     Religion              Caste Mother Tongue            Profession  \
# 0      hindu            maratha       english             scientist
# 1     muslim             hanafi          urdu           not working
# 2      hindu  brahmin himachali         hindi           not working
# 3      hindu               koli       kannada                doctor
# 4      hindu             kuruba       kannada   admin/ front office
# 5      hindu            brahmin       punjabi           not working
# 6   buddhist           buddhist       marathi                 other
# 7      hindu             rajput       kumoani            consultant
# 8      hindu        vishwakarma      bhojpuri  chartered accountant
# 9      hindu       brahmin gour         hindi           not working
# 10     hindu            maratha       english             scientist
# 11    muslim             hanafi          urdu           not working
# 12     hindu  brahmin himachali         hindi           not working
# 13     hindu               koli       kannada                doctor
# 14     hindu             kuruba       kannada   admin/ front office
# 15     hindu            brahmin       punjabi           not working
# 16  buddhist           buddhist       marathi                 other
# 17     hindu             rajput       kumoani            consultant
# 18     hindu        vishwakarma      bhojpuri  chartered accountant
# 19     hindu       brahmin gour         hindi           not working
#
#        Education  Age  Height in cm Height_ft_in Country             State  \
# 0   Postgraduate   26           162      5ft 4in   india       maharashtra
# 1       Graduate   21           154      5ft 1in   india         telangana
# 2       Graduate   35           162      5ft 4in   india  himachal pradesh
# 3   Postgraduate   30           162      5ft 4in   india         karnataka
# 4       Graduate   30           162      5ft 4in   india         karnataka
# 5         School   35           152      5ft 0in   india             delhi
# 6          Other   33           157      5ft 2in   india       maharashtra
# 7   Postgraduate   32           162      5ft 4in   india     uttar pradesh
# 8       Graduate   35           152      5ft 0in   india         jharkhand
# 9       Graduate   22           132      4ft 4in   india            odisha
# 10  Postgraduate   26           162      5ft 4in   india       maharashtra
# 11      Graduate   21           154      5ft 1in   india         telangana
# 12      Graduate   35           162      5ft 4in   india  himachal pradesh
# 13  Postgraduate   30           162      5ft 4in   india         karnataka
# 14      Graduate   30           162      5ft 4in   india         karnataka
# 15        School   35           152      5ft 0in   india             delhi
# 16         Other   33           157      5ft 2in   india       maharashtra
# 17  Postgraduate   32           162      5ft 4in   india     uttar pradesh
# 18      Graduate   35           152      5ft 0in   india         jharkhand
# 19      Graduate   22           132      4ft 4in   india            odisha
#
#              City  Gender Income Independency  Previous Marriage Addiction
# 0     navi mumbai  Female   High          Low                  0        No
# 1       hyderabad  Female    Low          Low                  0        No
# 2          shimla  Female    Low       Medium                  0        No
# 3           bidar  Female   High         High                  0       Yes
# 4       bangalore  Female    Low       Medium                  0        No
# 5       new delhi  Female    Low          Low                  0        No
# 6          wardha    Male    Low       Medium                  0        No
# 7   greater noida    Male    Low       Medium                  0        No
# 8      jamshedpur  Female    Low         High                  0        No
# 9         cuttack  Female    Low          Low                  1        No
# 10    navi mumbai    Male   High       Medium                  0       Yes
# 11      hyderabad    Male    Low          Low                  0       Yes
# 12         shimla  Female    Low         High                  1        No
# 13          bidar    Male   High       Medium                  0        No
# 14      bangalore    Male    Low         High                  0        No
# 15      new delhi    Male    Low       Medium                  0        No
# 16         wardha  Female    Low          Low                  0       Yes
# 17  greater noida  Female    Low         High                  0        No
# 18     jamshedpur  Female    Low          Low                  0        No
# 19        cuttack    Male    Low       Medium                  0        No
