# %%
import glob
import os.path
import joblib
import numpy as np
import pandas as pd
import sklearn
from sklearn import preprocessing

# %%
df = pd.read_csv("../../../data/raw/TrainingData/okcupid_profiles_1.csv")

# %%
df.head(4)
df.columns
# Out:
# Index(['age', 'status', 'sex', 'orientation', 'body_type', 'diet', 'drinks',
#        'drugs', 'education', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'pets', 'religion', 'sign',
#        'smokes', 'speaks', 'essay0', 'essay1', 'essay2', 'essay3', 'essay4',
#        'essay5', 'essay6', 'essay7', 'essay8', 'essay9'],
#       dtype='object')

# %%
columns = ['diet', 'drinks','last_online','pets','sign',
       'smokes','essay0', 'essay1', 'essay2', 'essay3', 'essay4',
       'essay5', 'essay6', 'essay7', 'essay8', 'essay9'] 
df.drop(columns= [c for c in columns], inplace=True)

# %%
df.head(20)
# Out:
#     age          status sex orientation       body_type      drugs  \
# 0    22          single   m    straight  a little extra      never
# 1    35          single   m    straight         average  sometimes
# 2    38       available   m    straight            thin        NaN
# 3    23          single   m    straight            thin        NaN
# 4    29          single   m    straight        athletic      never
# 5    29          single   m    straight         average        NaN
# 6    32          single   f    straight             fit      never
# 7    31          single   f    straight         average      never
# 8    24          single   f    straight             NaN        NaN
# 9    37          single   m    straight        athletic      never
# 10   35       available   m    straight         average        NaN
# 11   28  seeing someone   m    straight         average      never
# 12   24          single   m    straight             NaN        NaN
# ...
