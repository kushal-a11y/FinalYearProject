# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../../data/raw/TrainingData/marriage_data_india.csv")

# %%
len(df)
# Out:
# 10000

# %%
df.head()
df.drop(columns=["ID","Marriage_Type", "Parental_Approval","Dowry_Exchanged","Years_Since_Marriage","Children_Count"], inplace=True)
df.to_csv("../../../data/processed/TrainingData/marriage_data_india.csv")

# %%
df = pd.read_csv("../../../data/processed/TrainingData/marriage_data_india.csv")
df.head()
# Out:
#    Unnamed: 0  Age_at_Marriage  Gender Education_Level Caste_Match Religion  \
# 0           0               23    Male        Graduate   Different    Hindu
# 1           1               28  Female          School        Same    Hindu
# 2           2               39    Male    Postgraduate        Same   Muslim
# 3           3               26  Female          School   Different    Hindu
# 4           4               32  Female        Graduate        Same    Hindu
#
#   Urban_Rural Marital_Satisfaction Divorce_Status Income_Level Spouse_Working  \
# 0       Urban               Medium            Yes       Middle             No
# 1       Rural                  Low             No       Middle             No
# 2       Rural               Medium             No         High             No
# 3       Urban                  Low             No         High             No
# 4       Rural               Medium             No       Middle             No
#
#   Inter-Caste Inter-Religion
# ...

# %%
# Display value counts for each column
print("="*80)
print("VALUE COUNTS FOR EACH COLUMN")
print("="*80)

for col in df.columns:
    print(f"\n{col}:")
    print("-" * 50)
    print(df[col].value_counts())
    print(f"Total unique values: {df[col].nunique()}")
# Out:
# ...
# VALUE COUNTS FOR EACH COLUMN
# ...
#
# Unnamed: 0:
# --------------------------------------------------
# Unnamed: 0
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: count, Length: 10000, dtype: int64
# Total unique values: 10000
#
# Age_at_Marriage:
# --------------------------------------------------
# Age_at_Marriage
# 31    488
# 26    487
# 29    484
# 27    479
# 22    476
# 28    471
# 34    470
# 30    465
# 19    462
# 20    460
# 35    460
# 32    455
# 37    455
# 36    448
# 33    441
# 21    438
# 38    437
# 24    433
# 18    430
# 39    422
# 25    422
# 23    417
# Name: count, dtype: int64
# Total unique values: 22
#
# Gender:
# --------------------------------------------------
# Gender
# Female    5109
# Male      4891
# Name: count, dtype: int64
# Total unique values: 2
#
# Education_Level:
# --------------------------------------------------
# Education_Level
# ...

# %%
# Display value counts for each column
print("="*80)
print("VALUE COUNTS FOR EACH COLUMN")
print("="*80)

for col in df.columns:
    print(f"\n{col}:")
    print("-" * 50)
    print(df[col].value_counts())
    print(f"Total unique values: {df[col].nunique()}")
# Out:
# ...
# VALUE COUNTS FOR EACH COLUMN
# ...
#
# Unnamed: 0:
# --------------------------------------------------
# Unnamed: 0
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: count, Length: 10000, dtype: int64
# Total unique values: 10000
#
# Age_at_Marriage:
# --------------------------------------------------
# Age_at_Marriage
# 31    488
# 26    487
# 29    484
# 27    479
# 22    476
# 28    471
# 34    470
# 30    465
# 19    462
# 20    460
# 35    460
# 32    455
# 37    455
# 36    448
# 33    441
# 21    438
# 38    437
# 24    433
# 18    430
# 39    422
# 25    422
# 23    417
# Name: count, dtype: int64
# Total unique values: 22
#
# Gender:
# --------------------------------------------------
# Gender
# Female    5109
# Male      4891
# Name: count, dtype: int64
# Total unique values: 2
#
# Education_Level:
# --------------------------------------------------
# Education_Level
# ...
