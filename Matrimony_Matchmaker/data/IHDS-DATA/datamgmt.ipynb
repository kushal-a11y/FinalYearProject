# %%
import pandas as pd

# %%
df = pd.read_stata(r"D:\FinalYearProject\Matrimony_Matchmaker\data\IHDS-DATA\36151-0001-Data.dta")
df.to_csv(r"D:\FinalYearProject\Matrimony_Matchmaker\data\IHDS-DATA\data1.csv")

# %%
df = pd.read_csv(r"D:\FinalYearProject\Matrimony_Matchmaker\data\IHDS-DATA\data1.csv")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4544\922669899.py:1: DtypeWarning: Columns (46,51,72,222,324,325,326,329,330,331) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\FinalYearProject\Matrimony_Matchmaker\data\IHDS-DATA\data1.csv")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 df = pd.read_csv(r"D:\FinalYearProject\Matrimony_Matchmaker\data\IHDS-DATA\data1.csv")
# ----> 2 df.head(low_memory=False)
#
# TypeError: NDFrame.head() got an unexpected keyword argument 'low_memory'
